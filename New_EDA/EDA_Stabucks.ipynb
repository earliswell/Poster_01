# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data/starbucks.csv')
df.head()
# Out:
#    개방자치단체코드                    관리번호       인허가일자  영업상태구분코드  영업상태명  상세영업상태코드  \
# 0   3020000  3020000-104-1998-02305  1998-03-04         1  영업/정상         1
# 1   3120000  3120000-104-1999-03908  1999-07-15         1  영업/정상         1
# 2   3220000  3220000-104-2000-21264  2000-02-15         3     폐업         2
# 3   3220000  3220000-104-2000-21725  2000-05-08         3     폐업         2
# 4   3180000  3180000-104-2000-13733  2000-09-30         1  영업/정상         1
#
#   상세영업상태명        폐업일자  휴업시작일자  휴업종료일자  ...  소재지우편번호  \
# 0      영업         NaN     NaN     NaN  ...  140-133
# 1      영업         NaN     NaN     NaN  ...  120-808
# 2      폐업  2011-01-20     NaN     NaN  ...  135-932
# 3      폐업  2004-10-06     NaN     NaN  ...  135-090
# 4      영업         NaN     NaN     NaN  ...  150-876
#
#                                            소재지전체주소  \
# 0               서울특별시 용산구 청파동3가 111-35 가동 지상1,2,3층
# 1  서울특별시 서대문구 대현동 54-4 외 2필지(54-5,54-31) 신흥빌딩 1~3층
# ...

# %%
df['인허가일자'] = pd.to_datetime(df['인허가일자'])
df['폐업일자'] = pd.to_datetime(df['폐업일자'])

# %%
df['Start_Year'] = df['인허가일자'].dt.year
df['Start_Q'] = df['인허가일자'].dt.quarter
df['End_Year'] = df['폐업일자'].dt.year
df['End_Q'] = df['폐업일자'].dt.quarter

# %%
start_date = '2011-01-01'
end_date = '2020-03-31'

df = df[~(df['인허가일자'] > end_date)]

# %%
df = df[~(df['폐업일자'] < start_date)]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head(1)
# Out:
#    개방자치단체코드                    관리번호      인허가일자  영업상태구분코드  영업상태명  상세영업상태코드  \
# 0   3020000  3020000-104-1998-02305 1998-03-04         1  영업/정상         1
#
#   상세영업상태명 폐업일자  휴업시작일자  휴업종료일자  ...     사업장명 업태구분명       좌표정보(x)  \
# 0      영업  NaT     NaN     NaN  ...  스타벅스숙대점   커피숍  197035.08396
#
#          좌표정보(y)  위생업태명   시설총규모 Start_Year  Start_Q  End_Year End_Q
# 0  449151.762231    커피숍  432.28       1998        1       NaN   NaN
#
# [1 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['개방자치단체코드', '관리번호', '인허가일자', '영업상태구분코드', '영업상태명', '상세영업상태코드', '상세영업상태명',
#        '폐업일자', '휴업시작일자', '휴업종료일자', '소재지면적', '소재지우편번호', '소재지전체주소', '도로명전체주소',
#        '도로명우편번호', '사업장명', '업태구분명', '좌표정보(x)', '좌표정보(y)', '위생업태명', '시설총규모',
#        'Start_Year', 'Start_Q', 'End_Year', 'End_Q'],
#       dtype='object')

# %%
df = df[['인허가일자', '상세영업상태명', '폐업일자', '소재지면적', '소재지우편번호', '소재지전체주소', '도로명전체주소', '도로명우편번호',
        '사업장명', '좌표정보(x)', '좌표정보(y)', '시설총규모', 'Start_Year', 'Start_Q', 'End_Year', 'End_Q']]

# %%
df.to_csv('./data/starbucks_2011_2020.csv', index=False)

# %%
df
# Out:
#          인허가일자 상세영업상태명       폐업일자   소재지면적  소재지우편번호  \
# 0   1998-03-04      영업        NaT  432.28  140-133
# 1   1999-07-15      영업        NaT  217.56  120-808
# 2   2000-02-15      폐업 2011-01-20  528.00  135-932
# 3   2000-09-30      영업        NaT  203.30  150-876
# 4   2000-10-04      폐업 2011-06-22  114.38  137-713
# ..         ...     ...        ...     ...      ...
# 587 2019-11-29      영업        NaT  199.00  136-813
# 588 2019-12-20      영업        NaT  380.83  133-809
# 589 2020-02-13      영업        NaT  204.49  139-848
# 590 2020-03-16      영업        NaT  111.80  110-746
# 591 2020-03-23      영업        NaT  224.36  157-210
#
#                                              소재지전체주소  \
# 0                 서울특별시 용산구 청파동3가 111-35 가동 지상1,2,3층
# 1    서울특별시 서대문구 대현동 54-4 외 2필지(54-5,54-31) 신흥빌딩 1~3층
# 2                              서울특별시 강남구 역삼동 820-8번지
# 3                               서울특별시 영등포구 여의도동 23-9
# 4                     서울특별시 서초구 반포동 19-3번지 신세계백화점 2층
# ...
